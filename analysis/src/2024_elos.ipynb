# %%
from elos.elo_tracker import EloTracker
from utils.generic_utils import load_all_games_csv, get_teams, plot_elo_ratings_over_time

# %% [markdown]
# # Preliliminary Exploration
#
# This is a proof-of-concept notebook of building a working system of Elo updates using just the 2024 MLB season.

# %% [markdown]
# ## Get all Games

# %%
all_games = load_all_games_csv('../data/gameinfo_cleaned.csv')
# Out:
# /Users/lancehendricks/Documents/College Coding/ML/Elo Ratings/analysis/src/utils/generic_utils.py:30: DtypeWarning: Columns (10,11,13,17,19,20,21,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_games = pd.read_csv(filename)

# %% [markdown]
# ## Get 2024 Season Games

# %%
games_24 = all_games[all_games['season']==2024]
games_24.head()
# Out:
#              visteam hometeam   site      date  number starttime daynight  \
# gid
# SDN202403200     LAN      SDN  SEO01  20240320     0.0    7:05PM    night
# LAN202403210     SDN      LAN  SEO01  20240321     0.0    7:05PM    night
# ARI202403280     COL      ARI  PHO01  20240328     0.0    7:10PM    night
# BAL202403280     ANA      BAL  BAL12  20240328     0.0    3:05PM      day
# CHA202403280     DET      CHA  CHI12  20240328     0.0    3:10PM      day
#
#               innings  tiebreaker usedh  ... homerestdays  visrestdays  \
# gid                                      ...
# SDN202403200      9.0         2.0  True  ...        171.0        161.0
# LAN202403210      9.0         2.0  True  ...          1.0          1.0
# ARI202403280      9.0         2.0  True  ...        148.0        179.0
# BAL202403280      9.0         2.0  True  ...        170.0        179.0
# CHA202403280      9.0         2.0  True  ...        179.0        179.0
#
#              homepitcherrgs vispitcherrgs hometeamrgs visteamrgs  \
# gid
# SDN202403200           39.0          39.0        39.0       39.0
# LAN202403210           39.0          39.0        54.9       53.9
# ARI202403280           39.0          39.0        39.0       39.0
# BAL202403280           39.0          39.0        39.0       39.0
# CHA202403280           39.0          39.0        39.0       39.0
#
#              homepitcherminusteamrgs vispitcherminusteamrgs homelastkwinpct  \
# gid
# SDN202403200                     0.0                    0.0             NaN
# LAN202403210                   -15.9                  -14.9             1.0
# ARI202403280                     0.0                    0.0             NaN
# BAL202403280                     0.0                    0.0             NaN
# CHA202403280                     0.0                    0.0             NaN
#
#              vislastkwinpct
# gid
# SDN202403200            NaN
# LAN202403210            0.0
# ARI202403280            NaN
# BAL202403280            NaN
# CHA202403280            NaN
#
# [5 rows x 61 columns]

# %% [markdown]
# ## Elo Ratings Updates for 2024 Season

# %%
et = EloTracker()

et.add_history(games_24, add_elos_to_df=True)
# Out:
# {'SEA', 'SLN', 'WAS', 'SDN', 'BOS', 'LAN', 'ARI', 'MIN', 'OAK', 'MIA', 'TEX', 'CLE', 'NYN', 'COL', 'PHI', 'PIT', 'SFN', 'HOU', 'BAL', 'CIN', 'KCA', 'ATL', 'TBA', 'DET', 'ANA', 'MIL', 'CHN', 'NYA', 'CHA', 'TOR'} {'SEA', 'SLN', 'WAS', 'SDN', 'BOS', 'LAN', 'ARI', 'MIN', 'OAK', 'MIA', 'TEX', 'CLE', 'NYN', 'COL', 'PHI', 'PIT', 'SFN', 'HOU', 'BAL', 'CIN', 'KCA', 'ATL', 'TBA', 'DET', 'ANA', 'MIL', 'CHN', 'NYA', 'CHA', 'TOR'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 teams = get_teams(games_24)
#       2 et = EloTracker(teams)
# ----> 4 et.add_history(games_24, add_elos_to_df=True)
#
# File ~/Documents/College Coding/ML/Elo Ratings/analysis/src/elos/elo_tracker.py:119, in EloTracker.add_history(self, game_df, add_elos_to_df, add_win_probs_to_df)
#     115 away_won = 1 - home_won
#     117 print(initial_home_elo, initial_away_elo)
# --> 119 home_win_prob = self.elo_prob_func(initial_home_elo, initial_away_elo, game)
#     121 updated_home_elo, updated_away_elo = elo_update(initial_home_elo, initial_away_elo,
#     122                                                                home_won, home_win_prob, self.K,
#     123                                                                game, self.use_margin_of_victory)
#     125 if add_elos_to_df:
#
# File ~/Documents/College Coding/ML/Elo Ratings/analysis/src/utils/generic_utils.py:132, in basic_win_prob_for_et(home_elo, away_elo, game_info)
#     129 def basic_win_prob_for_et(home_elo: float, away_elo: float, game_info: pd.Series) -> float:
#     130     """Wrapper around basic_win_prob with game_info as an additional game_info arg to be compatible
#     131     for use in an EloTracker object."""
# --> 132     return basic_win_prob(home_elo, away_elo)
#
# File ~/Documents/College Coding/ML/Elo Ratings/analysis/src/utils/generic_utils.py:127, in basic_win_prob(home_elo, away_elo)
#     114 def basic_win_prob(home_elo: float, away_elo: float) -> float:
#     115     """Fetches the basic Elo probability the home team wins, given each team's Elo, along
#     116     with game_info, storing additional game info.
#     117
#    (...)    125         float: The basic probability the home team wins.
#     126     """
# --> 127     return 1 / (1+10**((away_elo - home_elo) / 400))
#
# TypeError: unsupported operand type(s) for /: 'set' and 'int'

# %%
# Example: Mariners
plot_elo_ratings_over_time('SEA', games_24)
