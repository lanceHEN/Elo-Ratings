# %%
import pandas as pd
from typing import Tuple
import math
import numpy as np
from tqdm import tqdm

# %% [markdown]
# # Cleaning Game Info
# This notebook provides a clean version of the raw `data/gameinfo.csv` file.
# If does the following:
# 1. Filtering for competitive games.
# 2. Adding a 'homewon' column, that is True if the home team won and False otherwise.
# 3. Adding a 'timestamp' column, which provides a `pd.Timestamp` for the game start time.
# 4. Adding an 'visdistancetraveled' column, which contains the distance in miles from the visiting team's stadium to the home team's stadium.
# 5. Adding 'homerestdays' and 'visrestdays' columns, which contains the number of days between the current game and the previous game for the home and visiting teams.
# 6. Save to a new csv, `.data/gameinfo_clean.csv`

# %%
pd.set_option('display.max_columns', None)

# %%
all_games = pd.read_csv('./gameinfo.csv')
all_games.head()
# Out:
# /var/folders/f3/w3vlb72x47z3vhjsm9s6jlxc0000gn/T/ipykernel_4746/2207742255.py:1: DtypeWarning: Columns (10,11,13,17,19,21,27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_games = pd.read_csv('./gameinfo.csv')
#             gid visteam hometeam   site      date  number starttime daynight  \
# 0  LS3189904140     CHN      LS3  LOU03  18990414     0.0    0:00PM      day
# 1  PHI189904140     WSN      PHI  PHI09  18990414     0.0    0:00PM      day
# 2  BLN189904150     NY1      BLN  BAL07  18990415     0.0    0:00PM      day
# 3  BRO189904150     BSN      BRO  NYC12  18990415     0.0    0:00PM      day
# 4  CIN189904150     PIT      CIN  CIN05  18990415     0.0    0:00PM      day
#
#    innings  tiebreaker  usedh htbf  timeofgame attendance fieldcond   precip  \
# 0      NaN         NaN  False  NaN       113.0    11500.0   unknown  unknown
# 1      NaN         NaN  False  NaN       120.0    12000.0   unknown  unknown
# 2      NaN         NaN  False  NaN       130.0     3912.0   unknown  unknown
# 3      NaN         NaN  False  NaN       120.0    20167.0   unknown  unknown
# 4      NaN         NaN  False  NaN       130.0    10000.0   unknown  unknown
#
#        sky temp  winddir windspeed oscorer forfeit  suspend   umphome  \
# 0  unknown  0.0  unknown      -1.0     NaN     NaN      NaN  burno101
# 1  unknown  0.0  unknown      -1.0     NaN     NaN      NaN  huntj901
# 2  unknown  0.0  unknown      -1.0     NaN     NaN      NaN  emslb101
# 3  unknown  0.0  unknown      -1.0     NaN     NaN      NaN  andre101
# 4  unknown  0.0  unknown      -1.0     NaN     NaN      NaN  sware101
#
#       ump1b ump2b ump3b umplf umprf        wp        lp save gametype  vruns  \
# 0  warna901   NaN   NaN   NaN   NaN  grifc101  cunnb103  NaN  regular     15
# 1  connt901   NaN   NaN   NaN   NaN  piatw101  killf101  NaN  regular      5
# 2  bettw901   NaN   NaN   NaN   NaN  kitsf101  dohee101  NaN  regular      3
# 3  gaffj801   NaN   NaN   NaN   NaN  nichk101  kennb101  NaN  regular      1
# 4  warna901   NaN   NaN   NaN   NaN  tannj101  hawlp101  NaN  regular      5
#
#    hruns wteam lteam line batteries lineups box  pbp  season
# 0      1   CHN   LS3    y      both       y   y  NaN    1899
# 1      6   PHI   WSN    y      both       y   y  NaN    1899
# 2      5   BLN   NY1    y      both       y   y  NaN    1899
# 3      0   BSN   BRO    y      both       y   y  NaN    1899
# 4      2   PIT   CIN    y      both       y   y  NaN    1899

# %% [markdown]
# ## 1. Filter for Competitive Games

# %%
valid_games = ['regular', 'championship', 'worldseries', 'lcs',
                'playoff', 'divisionseries', 'wildcard']

all_games = all_games[all_games['gametype'].isin(valid_games)].reset_index(drop=True)

# %% [markdown]
# ## 2. Add 'homewon' Column

# %%
all_games['homewon'] = list((all_games['hruns'] > all_games['vruns']))
all_games.head()
# Out:
#             gid visteam hometeam   site      date  number starttime daynight  \
# 0  LS3189904140     CHN      LS3  LOU03  18990414     0.0    0:00PM      day
# 1  PHI189904140     WSN      PHI  PHI09  18990414     0.0    0:00PM      day
# 2  BLN189904150     NY1      BLN  BAL07  18990415     0.0    0:00PM      day
# 3  BRO189904150     BSN      BRO  NYC12  18990415     0.0    0:00PM      day
# 4  CIN189904150     PIT      CIN  CIN05  18990415     0.0    0:00PM      day
#
#    innings  tiebreaker  usedh htbf  timeofgame attendance fieldcond   precip  \
# 0      NaN         NaN  False  NaN       113.0    11500.0   unknown  unknown
# 1      NaN         NaN  False  NaN       120.0    12000.0   unknown  unknown
# 2      NaN         NaN  False  NaN       130.0     3912.0   unknown  unknown
# 3      NaN         NaN  False  NaN       120.0    20167.0   unknown  unknown
# 4      NaN         NaN  False  NaN       130.0    10000.0   unknown  unknown
#
#        sky temp  winddir windspeed oscorer forfeit  suspend   umphome  \
# 0  unknown  0.0  unknown      -1.0     NaN     NaN      NaN  burno101
# 1  unknown  0.0  unknown      -1.0     NaN     NaN      NaN  huntj901
# 2  unknown  0.0  unknown      -1.0     NaN     NaN      NaN  emslb101
# 3  unknown  0.0  unknown      -1.0     NaN     NaN      NaN  andre101
# 4  unknown  0.0  unknown      -1.0     NaN     NaN      NaN  sware101
#
#       ump1b ump2b ump3b umplf umprf        wp        lp save gametype  vruns  \
# 0  warna901   NaN   NaN   NaN   NaN  grifc101  cunnb103  NaN  regular     15
# 1  connt901   NaN   NaN   NaN   NaN  piatw101  killf101  NaN  regular      5
# 2  bettw901   NaN   NaN   NaN   NaN  kitsf101  dohee101  NaN  regular      3
# 3  gaffj801   NaN   NaN   NaN   NaN  nichk101  kennb101  NaN  regular      1
# 4  warna901   NaN   NaN   NaN   NaN  tannj101  hawlp101  NaN  regular      5
#
#    hruns wteam lteam line batteries lineups box  pbp  season  homewon
# 0      1   CHN   LS3    y      both       y   y  NaN    1899    False
# 1      6   PHI   WSN    y      both       y   y  NaN    1899     True
# 2      5   BLN   NY1    y      both       y   y  NaN    1899     True
# 3      0   BSN   BRO    y      both       y   y  NaN    1899    False
# 4      2   PIT   CIN    y      both       y   y  NaN    1899    False

# %% [markdown]
# ## 3. Add 'timestamp' Column

# %%
def get_hms(raw_starttime: str) -> Tuple[int, int]:
    """For the given raw start time (e.g. '5:30PM'), returns the hour and minute.
    
    If raw_starttime is nan, this will return 0, 0.
    
    If there is no 'AM' or 'PM' (e.g., '' or '?M'), it will assume a 24 hour clock.
    """

    if pd.isna(raw_starttime):
        return 0, 0
    
    col_idx = raw_starttime.find(':')
    h = int(raw_starttime[:col_idx]) 
    m = int(raw_starttime[col_idx + 1:col_idx + 3])
    
    # If AM or PM, need to do some more conversions
        
    # If time is PM and not 12:00, add 12 hours
    # Note some entries in all_games are 0:00 PM - this would also correctly add 12 hours,
    # making it the familiar 12:00 PM
    if raw_starttime[-2:].upper() == 'PM' and h != 12:
        h += 12
            
    elif raw_starttime[-2:].upper() == 'AM' and h == 12: # Edge case - if midnight, h should be 0
        h = 0
        
    return h, m

def get_timestamp(game: pd.DataFrame) -> pd.Timestamp:
    """For a single row, gets its game start timestamp."""
    #print(game['starttime'])
    h, min = get_hms(game['starttime'])
    
    raw_date = str(game['date'])

    y = int(raw_date[:4])
    mon = int(raw_date[4:6])
    d = int(raw_date[6:])
    return pd.Timestamp(year=y, month=mon, day=d, hour=h, minute=min)

# %%
# Add the timestamp column

all_games['timestamp'] = all_games.apply(get_timestamp, axis=1)
all_games.head()

# %% [markdown]
# ## 4. Add 'visdistancetraveled' Column

# %%
# Add temporary latitude and longitude columns
parks = pd.read_csv('Parks.csv')
all_games = pd.merge(all_games, parks[['PARKID', 'Latitude', 'Longitude']], how='left', left_on='site', right_on='PARKID').reset_index(drop=True)
all_games = all_games.drop('PARKID', axis=1)

# %%
def haversine(lat1, lon1, lat2, lon2):
    """Returns Haversine distance between two pairs of latitudes and longitudes."""
    R = 3958.8  # Earth radius in miles
    phi1, phi2 = math.radians(lat1), math.radians(lat2)
    dphi = math.radians(lat2 - lat1)
    dlambda = math.radians(lon2 - lon1)
    a = math.sin(dphi / 2)**2 + math.cos(phi1) * math.cos(phi2) * math.sin(dlambda / 2)**2
    return 2 * R * math.atan2(math.sqrt(a), math.sqrt(1 - a))

# %%
away_dists = []
n_games = all_games.shape[0]
for i, game in tqdm(all_games.iterrows()):
    
    cur_lat = game['Latitude']
    cur_lon = game['Longitude']
    
    away_team = game['visteam']
    
    # Get lat and lon of the closest home game they played
    before = i - 1
    after = i + 1
    while before >= 0 or after <= n_games - 1:
        if before >= 0:
            before_gm = all_games.iloc[before]
            if before_gm['hometeam'] == away_team:
                away_lat = before_gm['Latitude']
                away_lon = before_gm['Longitude']
                break
            
        if after <= n_games - 1:
            after_gm = all_games.iloc[after]
            if after_gm['hometeam'] == away_team:
                away_lat = after_gm['Latitude']
                away_lon = after_gm['Longitude']
                break
        
        if before >= 0:   
            before -= 1
        if after <= n_games - 1:
            after += 1

    else: # We never saw them play home, so we have no idea where they play - leave na.
        away_dists.append(np.nan)
        continue
        
    away_dists.append(haversine(away_lat, away_lon, cur_lat, cur_lon))
    
all_games['visdistancetraveled'] = away_dists
# Out:
# 218699it [08:18, 438.41it/s]

# %% [markdown]
# ## 5. Add Rest Day Columns

# %% [markdown]
# ### Home Rest Days

# %%
home_rest_days = []
away_rest_days = []

last_played = {}

for _, game in tqdm(all_games.iterrows()):
    home_team = game['hometeam']
    away_team = game['visteam']
    timestamp = game['timestamp']
    
    prev_home_t = last_played.get(home_team)
    prev_away_t = last_played.get(away_team)
    
    home_rest_days.append((timestamp.floor('D') - prev_home_t.floor('D')).days if prev_home_t is not None else np.nan)
    away_rest_days.append((timestamp.floor('D') - prev_away_t.floor('D')).days if prev_away_t is not None else np.nan)

    last_played[home_team] = timestamp
    last_played[away_team] = timestamp
 
all_games['homerestdays'] = home_rest_days
all_games['visrestdays'] = away_rest_days
# Out:
# 0it [00:00, ?it/s]
# 218699it [03:39, 997.98it/s]

# %%
all_games.tail(20)
# Out:
#                  gid visteam hometeam   site      date  number starttime  \
# 218679  DET202410100     CLE      DET  DET05  20241010     0.0    6:08PM
# 218680  KCA202410100     NYA      KCA  KAN06  20241010     0.0    7:08PM
# 218681  LAN202410110     SDN      LAN  LOS03  20241011     0.0    5:08PM
# 218682  CLE202410120     DET      CLE  CLE08  20241012     0.0    1:08PM
# 218683  LAN202410130     NYN      LAN  LOS03  20241013     0.0    5:15PM
# 218684  LAN202410140     NYN      LAN  LOS03  20241014     0.0    1:08PM
# 218685  NYA202410140     CLE      NYA  NYC21  20241014     0.0    7:38PM
# 218686  NYA202410150     CLE      NYA  NYC21  20241015     0.0    7:38PM
# 218687  NYN202410160     LAN      NYN  NYC20  20241016     0.0    8:08PM
# 218688  CLE202410170     NYA      CLE  CLE08  20241017     0.0    5:08PM
# 218689  NYN202410170     LAN      NYN  NYC20  20241017     0.0    8:08PM
# 218690  CLE202410180     NYA      CLE  CLE08  20241018     0.0    8:08PM
# 218691  NYN202410180     LAN      NYN  NYC20  20241018     0.0    5:08PM
# 218692  CLE202410190     NYA      CLE  CLE08  20241019     0.0    8:08PM
# 218693  LAN202410200     NYN      LAN  LOS03  20241020     0.0    5:08PM
# 218694  LAN202410250     NYA      LAN  LOS03  20241025     0.0    5:08PM
# 218695  LAN202410260     NYA      LAN  LOS03  20241026     0.0    5:08PM
# 218696  NYA202410280     LAN      NYA  NYC21  20241028     0.0    8:08PM
# 218697  NYA202410290     LAN      NYA  NYC21  20241029     0.0    8:08PM
# 218698  NYA202410300     LAN      NYA  NYC21  20241030     0.0    8:08PM
#
#        daynight  innings  tiebreaker usedh htbf  timeofgame attendance  \
# 218679    night      9.0         NaN  True  NaN       185.0      44923
# 218680    night      9.0         NaN  True  NaN       156.0      39012
# 218681    night      9.0         NaN  True  NaN       146.0      53183
# 218682      day      9.0         NaN  True  NaN       188.0      34105
# 218683    night      9.0         NaN  True  NaN       172.0      53503
# 218684      day      9.0         NaN  True  NaN       207.0      52926
# 218685    night      9.0         NaN  True  NaN       181.0      47264
# 218686    night      9.0         NaN  True  NaN       206.0      47054
# 218687    night      9.0         NaN  True  NaN       191.0      43883
# 218688    night      9.0         NaN  True  NaN       232.0      32531
# 218689    night      9.0         NaN  True  NaN       219.0      43882
# 218690    night      9.0         NaN  True  NaN       207.0      35263
# 218691    night      9.0         NaN  True  NaN       188.0      43841
# 218692    night      9.0         NaN  True  NaN       216.0      32545
# 218693    night      9.0         NaN  True  NaN       195.0      52674
# 218694    night      9.0         NaN  True  NaN       207.0      52394
# 218695    night      9.0         NaN  True  NaN       173.0      52725
# 218696    night      9.0         NaN  True  NaN       205.0      49368
# 218697    night      9.0         NaN  True  NaN       196.0      49354
# 218698    night      9.0         NaN  True  NaN       222.0      49263
#
#        fieldcond precip     sky temp winddir windspeed   oscorer forfeit  \
# 218679   unknown   none   sunny   61  fromcf         2  kleir701     NaN
# 218680   unknown   none   sunny   78    rtol         6  butcp701     NaN
# 218681   unknown   none  cloudy   80    ltor         2  munse701     NaN
# 218682   unknown   none   sunny   65  fromcf         7  maveb701     NaN
# 218683   unknown   none   sunny   73    tocf         5  munse701     NaN
# 218684   unknown   none  cloudy   73    tocf         6  eastr701     NaN
# 218685   unknown   none  cloudy   50    ltor        15  karph701     NaN
# 218686   unknown   none  cloudy   52    ltor         2  kaplh701     NaN
# 218687   unknown   none   sunny   51    ltor         8  kaplh701     NaN
# 218688   unknown   none   sunny   57  fromcf         5  libea701     NaN
# 218689   unknown   none   sunny   53  fromlf         8  altmb701     NaN
# 218690   unknown   none   sunny   56  fromrf         5  maveb701     NaN
# 218691   unknown   none   sunny   67  fromlf         7  sprej701     NaN
# 218692   unknown   none   sunny   58  fromcf         5  brosc701     NaN
# 218693   unknown   none   sunny   78    tocf         4  munse701     NaN
# 218694   unknown   none   sunny   76    rtol         5  munse701     NaN
# 218695   unknown   none  cloudy   77    ltor         5  munse701     NaN
# 218696   unknown   none   sunny   52  fromlf         5  altmb701     NaN
# 218697   unknown   none  cloudy   61    rtol        10  karph701     NaN
# 218698   unknown   none  cloudy   67    tolf         5  sprej701     NaN
#
#         suspend   umphome     ump1b     ump2b     ump3b     umplf     umprf  \
# 218679      NaN  ticht901  fairc901  mahrn901  becka901  dejer901  wolfj901
# 218680      NaN  carlm901  barkl901  ortir901  hamaa901  blakr901  barrl901
# 218681      NaN  gibsh902  johna901  rippm901  libkj901  blasc901  belld901
# 218682      NaN  fairc901  mahrn901  becka901  dejer901  wolfj901  ticht901
# 218683      NaN  rehaj901  hudsm901  lentn901  millb901  rackd901  bakej902
# 218684      NaN  muchm901  lentn901  millb901  rackd901  bakej902  rehaj901
# 218685      NaN  estam901  iassd901  segac901  porta901  viscj901  carav901
# 218686      NaN  morag901  segac901  porta901  viscj901  carav901  estam901
# 218687      NaN  hudsm901  millb901  rackd901  bakej902  rehaj901  muchm901
# 218688      NaN  iassd901  porta901  viscj901  carav901  estam901  morag901
# 218689      NaN  lentn901  rackd901  bakej902  rehaj901  muchm901  hudsm901
# 218690      NaN  segac901  viscj901  carav901  estam901  morag901  iassd901
# 218691      NaN  millb901  bakej902  rehaj901  muchm901  hudsm901  lentn901
# 218692      NaN  porta901  carav901  estam901  morag901  iassd901  segac901
# 218693      NaN  rackd901  rehaj901  muchm901  hudsm901  lentn901  millb901
# 218694      NaN  torrc901  carlm901  eddid901  rippm901  fairc901  ticht901
# 218695      NaN  fleta901  eddid901  rippm901  fairc901  ticht901  torrc901
# 218696      NaN  carlm901  rippm901  fairc901  ticht901  torrc901  fleta901
# 218697      NaN  eddid901  fairc901  ticht901  torrc901  fleta901  carlm901
# 218698      NaN  rippm901  ticht901  torrc901  fleta901  carlm901  eddid901
#
#               wp        lp      save        gametype  vruns  hruns wteam  \
# 218679  gaddh001  brieb001  clase001  divisionseries      5      4   CLE
# 218680  coleg001  wachm001  weavl001  divisionseries      3      1   NYA
# 218681  yamay001  darvy001  treib001  divisionseries      0      2   LAN
# 218682  herrt002  skubt001  clase001  divisionseries      3      7   CLE
# 218683  flahj002  sengk001       NaN             lcs      0      9   LAN
# 218684  manas001  brasr001  diaze006             lcs      7      3   NYN
# 218685  rodoc001  cobba001  weavl001             lcs      2      5   NYA
# 218686  holmc001  bibet001       NaN             lcs      3      6   NYA
# 218687  kopem001  sevel001       NaN             lcs      8      0   LAN
# 218688  avilp001  holmc001       NaN             lcs      5      7   CLE
# 218689  phile001  quinj001       NaN             lcs     10      2   LAN
# 218690  leitm002  clase001  kahnt001             lcs      8      6   NYA
# 218691  stanr002  flahj002       NaN             lcs      6     12   NYN
# 218692  weavl001  gaddh001       NaN             lcs      5      2   NYA
# 218693  caspb001  manas001  treib001             lcs      5     10   LAN
# 218694  treib001  cousj001       NaN     worldseries      3      6   LAN
# 218695  yamay001  rodoc001  vesia001     worldseries      2      4   LAN
# 218696  buehw001  schmc002       NaN     worldseries      4      2   LAN
# 218697  holmc001  hudsd001       NaN     worldseries      4     11   NYA
# 218698  treib001  kahnt001  buehw001     worldseries      7      6   LAN
#
#        lteam line batteries lineups box pbp  season  homewon  \
# 218679   DET    y      both       y   y   y    2024    False
# 218680   KCA    y      both       y   y   y    2024    False
# 218681   SDN    y      both       y   y   y    2024     True
# 218682   DET    y      both       y   y   y    2024     True
# 218683   NYN    y      both       y   y   y    2024     True
# 218684   LAN    y      both       y   y   y    2024    False
# 218685   CLE    y      both       y   y   y    2024     True
# 218686   CLE    y      both       y   y   y    2024     True
# 218687   NYN    y      both       y   y   y    2024    False
# 218688   NYA    y      both       y   y   y    2024     True
# 218689   NYN    y      both       y   y   y    2024    False
# 218690   CLE    y      both       y   y   y    2024    False
# 218691   LAN    y      both       y   y   y    2024     True
# 218692   CLE    y      both       y   y   y    2024    False
# 218693   NYN    y      both       y   y   y    2024     True
# 218694   NYA    y      both       y   y   y    2024     True
# 218695   NYA    y      both       y   y   y    2024     True
# 218696   NYA    y      both       y   y   y    2024    False
# 218697   LAN    y      both       y   y   y    2024     True
# 218698   NYA    y      both       y   y   y    2024    False
#
#                  timestamp   Latitude   Longitude  visdistancetraveled  \
# 218679 2024-10-10 18:08:00  42.339063  -83.048627            91.134933
# 218680 2024-10-10 19:08:00  39.051604  -94.480149          1093.203095
# 218681 2024-10-11 17:08:00  34.073878 -118.239951           113.202533
# 218682 2024-10-12 13:08:00  41.496005  -81.685326            91.134933
# 218683 2024-10-13 17:15:00  34.073878 -118.239951          2452.947708
# 218684 2024-10-14 13:08:00  34.073878 -118.239951          2452.947708
# 218685 2024-10-14 19:38:00  40.829586  -73.926413           406.072970
# 218686 2024-10-15 19:38:00  40.829586  -73.926413           406.072970
# 218687 2024-10-16 20:08:00  40.757134  -73.845840          2452.947708
# 218688 2024-10-17 17:08:00  41.496005  -81.685326           406.072970
# 218689 2024-10-17 20:08:00  40.757134  -73.845840          2452.947708
# 218690 2024-10-18 20:08:00  41.496005  -81.685326           406.072970
# 218691 2024-10-18 17:08:00  40.757134  -73.845840          2452.947708
# 218692 2024-10-19 20:08:00  41.496005  -81.685326           406.072970
# 218693 2024-10-20 17:08:00  34.073878 -118.239951          2452.947708
# 218694 2024-10-25 17:08:00  34.073878 -118.239951          2448.420713
# 218695 2024-10-26 17:08:00  34.073878 -118.239951          2448.420713
# 218696 2024-10-28 20:08:00  40.829586  -73.926413          2448.420713
# 218697 2024-10-29 20:08:00  40.829586  -73.926413          2448.420713
# 218698 2024-10-30 20:08:00  40.829586  -73.926413          2448.420713
#
#         homerestdays  visrestdays
# 218679             1            1
# 218680             1            1
# 218681             2            2
# 218682             2            2
# 218683             2            4
# 218684             1            1
# 218685             4            2
# 218686             1            1
# 218687             2            2
# 218688             2            2
# 218689             1            1
# 218690             1            1
# 218691             1            1
# 218692             1            1
# 218693             2            2
# 218694             5            6
# 218695             1            1
# 218696             2            2
# 218697             1            1
# 218698             1            1

# %% [markdown]
# ## 6. Save to `.csv`

# %%
all_games.to_csv('./gameinfo_cleaned.csv', index=False)
